# %%
# !git clone https://github.com/ultralytics/yolov5 # clone repo
# %cd yolov5
# !pip install -U -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9368, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 9368 (delta 12), reused 13 (delta 5), pack-reused 9338
# Receiving objects: 100% (9368/9368), 9.80 MiB | 24.18 MiB/s, done.
# Resolving deltas: 100% (6503/6503), done.
# /content/yolov5
# ...
#      |████████████████████████████████| 10.3 MB 9.6 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 190 kB/s
# ...
#      |████████████████████████████████| 49.9 MB 16 kB/s
# ...
#      |████████████████████████████████| 3.0 MB 40.2 MB/s
# ...
#      |████████████████████████████████| 636 kB 38.3 MB/s
# ...
#      |████████████████████████████████| 28.5 MB 45 kB/s
# ...
#      |████████████████████████████████| 76 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 292 kB 44.8 MB/s
# ...
#      |████████████████████████████████| 11.3 MB 37.8 MB/s
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
# ...

# %%
# !python train.py --data coco.yaml --epoch 1

# %%
import torch
weights = './runs/train/exp4/weights/last.pt'
ckpt = torch.load(weights) 
ckpt
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-0188dcba5922> in <module>()
#       1 import torch
#       2 weights = './runs/train/exp4/weights/last.pt'
# ----> 3 ckpt = torch.load(weights)
#       4 ckpt
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     592         pickle_load_args['encoding'] = 'utf-8'
#     593
# --> 594     with _open_file_like(f, 'rb') as opened_file:
#     595         if _is_zipfile(opened_file):
#     596             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
# ...
